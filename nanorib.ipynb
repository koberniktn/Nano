# %%
from ase.build import graphene_nanoribbon
import nglview as nv

# %%
nanoribbon = graphene_nanoribbon(
    3, 1,
    type='zigzag',      # или 'armchair'
    saturated=False,    # пассивация водородом по краям
    C_H=1.09,
    C_C=1.42,
    vacuum=None,
    magnetic=False,
    initial_mag=1.12,
    sheet=False,
    main_element='C',
    saturate_element='H'
)

# %%
w = nv.show_ase(nanoribbon)
w.add_ball_and_stick()
w.add_label(color="black", labelType="atomindex")
w
# Out:
# NGLWidget()

# %%
from ase.build import graphene_nanoribbon

# zigzag-лента, ширина n=8, длина m=20, пассивированы края H, вакуум 10Å
ribbon = graphene_nanoribbon(
    n=8,
    m=20,
    type='zigzag',
    saturated=True,
    vacuum=10.0
)

# %%
w = nv.show_ase(ribbon)
w.add_ball_and_stick()
w.add_label(color="black", labelType="atomindex")
w
# Out:
# NGLWidget()

# %%
# координаты атомов (N×3 массив в Å)
coords = ribbon.get_positions()
cell   = ribbon.get_cell()
symbols = ribbon.get_chemical_symbols()

# %%
coords
# Out:
# array([[1.10900000e+01, 1.00000000e+01, 0.00000000e+00],
#        [1.18000000e+01, 1.00000000e+01, 1.22975607e+00],
#        [1.10900000e+01, 1.00000000e+01, 2.45951215e+00],
#        ...,
#        [2.78000000e+01, 1.00000000e+01, 4.42712186e+01],
#        [2.78000000e+01, 1.00000000e+01, 4.67307308e+01],
#        [2.78000000e+01, 1.00000000e+01, 7.10542736e-15]])

# %%
cell
# Out:
# Cell([37.8, 20.0, 49.19024293495611])
